# %%
import pandas as pd
df= pd.read_excel(r"C:\ML_Final_Project\notebooks\Data\OnlineKhabar_Posts_Final.xlsx")
df.head()
# Out:
#                                                Posts  \
# 0                      HoR passes Finance Bill, 2083
# 1               HoR passes Bill to Raise Public Debt
# 2  49 of RSP’s 99 elected central members are wom...
# 3  Who is to blame for the chaos at RSP’s convent...
# 4  RSP promised a smarter convention than its riv...
#
#                                                  URL
# 0  {'url': 'https://english.onlinekhabar.com/hor-...
# 1  {'url': 'https://english.onlinekhabar.com/hor-...
# 2  {'url': 'https://english.onlinekhabar.com/49-r...
# 3  {'url': 'https://english.onlinekhabar.com/chao...
# 4  {'url': 'https://english.onlinekhabar.com/rsp-...

# %%
import ast
df["URL"] = df["URL"].apply(ast.literal_eval)
df["Category"] = df["URL"].apply(lambda x: x["category"])
df["Link"] = df["URL"].apply(lambda x: x["url"])

# %%
df.head()
# Out:
#                                                Posts  \
# 0                      HoR passes Finance Bill, 2083
# 1               HoR passes Bill to Raise Public Debt
# 2  49 of RSP’s 99 elected central members are wom...
# 3  Who is to blame for the chaos at RSP’s convent...
# 4  RSP promised a smarter convention than its riv...
#
#                                                  URL  Category  \
# 0  {'url': 'https://english.onlinekhabar.com/hor-...  Politics
# 1  {'url': 'https://english.onlinekhabar.com/hor-...  Politics
# 2  {'url': 'https://english.onlinekhabar.com/49-r...  Politics
# 3  {'url': 'https://english.onlinekhabar.com/chao...  Politics
# 4  {'url': 'https://english.onlinekhabar.com/rsp-...  Politics
#
#                                                 Link
# 0  https://english.onlinekhabar.com/hor-passes-fi...
# 1  https://english.onlinekhabar.com/hor-passes-bi...
# 2  https://english.onlinekhabar.com/49-rsps-centr...
# 3  https://english.onlinekhabar.com/chaos-at-rsps...
# 4  https://english.onlinekhabar.com/rsp-promised-...

# %%
df.shape
# Out:
# (12394, 4)
